# %% [markdown]
# # CAJA NEGRA V2.0
# ## Descripción
# "El joven T se fue". Cambios, hay que hacer cambios dado que la caja negra cambio su ser, sigue siendo negra pero trabjara diferente, cambia tanto las entradas como las salidas y tambien las tripas del codigo, pero, ¿por que?. por varias razones, la primera es que tanto la entrada, como la salida de la anterior caja negra, no era la ideal para lo que se desea hacer en el proyecto de grado. puesto que un conjunto de puntos (long, lat) es un punto demasiado especifico, o demasiado grande, incluso de por si eso no se sabe, eso viene dado por la resolucion de la imagen, pues si uno busca en internet a bogota o cualquier otra ciudad, le van a netregar un par de puntos (long, lat) y si se busca una casa tambien se entregara un solo par de puntos (long. lat), no se sabe si la diferencia de ambos puntos es algun tipo de proecision, o cantidad de decimales, se peude buscar si, pero es algo muy complicado de manejar. Ademas se planean usar distintas resoluciones de la imagen satelital o como lo denomina google "Zoom", asi que tener un solo punto como entrada no es muy obtimo. Respecto a la salida, se tenia planteado que entregara un entero de 1 a 6, dependiendo del punto (long, lat) entregado, y esto genera varios problemas, dado que si se entregaba un unico punto (long, lat), esto no se sabia si representaba un unico pixel de la imagen o un conjunto de pixeles, y las imagenes al tener varios colores extras, como los colores morados de los nombres y si un punto (long, lat) cae sobre uno de estos pixeles morados, pues pailas por uqe debajo del morado debe haber un estrato. Para solucionar este problema teniendo en cuenta la entrada y la salida dada, se estaban editando las imágenes en Inkscape. Respecto a trbajar con un punto queda tambien complicado dado que el dataset iba a trabajar con imagenes y eso implica trabajr con un "area". El profesor se dio cuenta de esto y tambien de la edicion de las imagenes que se estaban realizando y dijo, en palabras de melike, mierda yo veo eso y digo mierda. Por ende se propone el siguiente modelo de caja negra, el cual es mas optimo para lo que se planea hacer.

# %% [markdown]
# <center>
# <div style="width:80%">
# <img src="./vector/Modelo_caja_negra.svg">
# <p><b><i> Figura 1. </i></b> Sistema propuesto para el Target</p>
# </div>
# </center>

# %% [markdown]
# Entonces, ¿por que manejar esta nueva entrada y esta nueva salida?. la entrada del centro y zoom es por que asi maneja Google su API de mapas. Yo obtengo de la API de Gooogle una imagen dando un centro y un zoom, y de esa imagen obtenida se debe tener el estrato, y segun la imagenes que use, que seran los pdf de bogota, debo entregar un vector con la cantidad de cada uno de esos estratos presentes en esa imagen pues dependiendo del zoom y del centro podria abarcar varios estratos o ninguno. No solo eso, si tambien para trabajar mejor con regresion que con clasificacion, ya que si se entrega un solo valor, el modelo tendria que predecir dicho valor, cambio con los porcentajes se haria una tarea de regression, dado que los valores no siempre seran los mismos. Aqui la mayor tarea es crear la relacion (centro, zoom) de la imagen de google con la relacion (centro, zoom) de la imagen.

# %% [markdown]
# ## Desarrollo.

# %% [markdown]
# #### GOOGLE API - Google Static Maps Developer Guide

# %%
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
KEY = "AIzaSyC6lM6tFm3orjg5yy6TxJOzcXns-Olx0Fg"
SIZE = "680x680" # No se puede mas grande. Habria que pagar

# %%
ZOOM = "19" # Numero de 1 al 20. 1 = Mundo, 20 = Construcciones
CENTER = "Bogota" # Nombre o par de coordanadas
MAPTYPE = "satellite" # roadmap, satellite, terrain, hybrid

# %%
img = io.imread("http://maps.googleapis.com/maps/api/staticmap?center="+CENTER+"&zoom="+ZOOM+"&key="+KEY+"&size="+SIZE+"&maptype="+MAPTYPE)

fig = plt.figure(figsize=(20,10))
plt.imshow(img, cmap = plt.cm.Greys_r)

# %%
fig = plt.figure(figsize=(20,10))
for i in range(20):
    ax=fig.add_subplot(4,5,i+1)
    plt.imshow(io.imread("http://maps.googleapis.com/maps/api/staticmap?center="+CENTER+"&zoom="+str(i+1)+"&key="+KEY+"&size="+SIZE+"&maptype="+MAPTYPE))
    ax.set_title("Zoom:" + str(i+1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])
