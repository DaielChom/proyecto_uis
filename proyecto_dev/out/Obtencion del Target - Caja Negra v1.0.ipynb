# %% [markdown]
# # Target
# "Estaré siendo exigente o realmente poco interes hay" <br/>
# **Contestación:** Es algo de exigencia eh infantilerias mias. <br/>
# Y hablando de exigencia, la presente tarea a realizar ta como dificil. la idea es tener ya de forma consisa el target se usará en el proyecto. En dibujos y palabras del profe Raul, se requiere lo siguiente.
#
# <center>
# <div style="width:60%">
# <img src="./vector/Recolectar_target.svg">
# <p><b><i> Figura 1. </i></b> Sistema propuesto para el Target</p>
# </div>
# </center>
#
# Hay varias cosas que decir, primero no necesariamente tiene que ser las cordenada de varias ciudades, podria ser solo de bogota o de *"lo que los datos nos digan".* Se tienen varias fuentes de datos, habria que escoger de una de ellas o tomar los datos de todas y hacer el sistema que se pide. Pdta: No se como empezar. Por ahora traigamos las fuentes del target.
#
# ## Fuentes:
#
# Se toman las fuentes consultadas en el notebook [Posibles Fuentes](./Posibles Fuentes de Datos.ipynb).
#
#   ### 1. arcGIS:
# ** DESCARTDA ** muy poquitos datos
# Consultamos la existencia del mapa

# %%
# uno de las posibles fuentes son los mapas de arcGIS, entoncs se importa su libreria
import arcgis
from arcgis.gis import GIS
from IPython.display import display

gis = GIS()
items = gis.content.search("estratificacion bogota")

items[2]
# Out:
# <Item title:"Estratificacion Bogota - Copiar" type:Feature Collection owner:Sergio1130>

# %% [markdown]
# Descargamos los datos

# %%
items[2].download("./Target/arcGIS/")
# Out:
# './Target/arcGIS/Estratificacion Bogota - Copiar'

# %% [markdown]
# Los leemos desde el disco

# %%
import json

archivo = open('./Target/arcGIS/Estratificacion Bogota - Copiar')
data_dict = json.load(archivo)
archivo.close()

# %% [markdown]
# Como se puede ver, los datos se obtuvieron, y hay referencia de una posicion geometrica y un estrato

# %%
import pandas as pd

data_dict.get('layers')[0].get('featureSet').get('features')
# Out:
# [{'attributes': {'ESTRATO': '1',
#    'FID': 0,
#    'MUNICIPIO': 'BOGOTA',
#    'OBJECTID': 1,
#    'Shape_Area': 1.76349764136e-07,
#    'Shape_Leng': 0.00169600118505},
#   'geometry': {'rings': [[[-8246601, 500775],
#      [-8246597, 500723],
#      [-8246649, 500727],
#      [-8246649, 500763],
#      [-8246601, 500775]]],
#    'spatialReference': {'wkid': 102100}}},
#  {'attributes': {'ESTRATO': '1',
#    'FID': 1,
#    'MUNICIPIO': 'BOGOTA',
#    'OBJECTID': 2,
#    'Shape_Area': 9.9718144763e-08,
#    'Shape_Leng': 0.00124267988348},
#   'geometry': {'rings': [[[-8249654, 503381],
#      [-8249688, 503381],
#      [-8249686, 503409],
#      [-8249658, 503424],
#      [-8249654, 503381]]],
#    'spatialReference': {'wkid': 102100}}},
#  {'attributes': {'ESTRATO': '1',
#    'FID': 2,
#    'MUNICIPIO': 'BOGOTA',
#    'OBJECTID': 3,
#    'Shape_Area': 9.93615007062e-08,
#    'Shape_Leng': 0.00124050440893},
#   'geometry': {'rings': [[[-8249850, 503426],
#      [-8249884, 503426],
#      [-8249882, 503454],
#      [-8249854, 503469],
#      [-8249850, 503426]]],
#    'spatialReference': {'wkid': 102100}}},
#  {'attributes': {'ESTRATO': '1',
#    'FID': 3,
#    'MUNICIPIO': 'BOGOTA',
#    'OBJECTID': 4,
#    'Shape_Area': 9.93615365177e-08,
#    'Shape_Leng': 0.00124050509586},
#   'geometry': {'rings': [[[-8249690, 503505],
#      [-8249724, 503505],
#      [-8249722, 503533],
#      [-8249695, 503548],
#      [-8249690, 503505]]],
#    'spatialReference': {'wkid': 102100}}},
#  {'attributes': {'ESTRATO': '1',
#    'FID': 4,
#    'MUNICIPIO': 'BOGOTA',
#    'OBJECTID': 5,
#    'Shape_Area': 9.95406902145e-08,
#    'Shape_Leng': 0.00124162726473},
#   'geometry': {'rings': [[[-8249600, 504435],
#      [-8249634, 504435],
#      [-8249632, 504463],
#      [-8249604, 504478],
#      [-8249600, 504435]]],
#    'spatialReference': {'wkid': 102100}}},
#  {'attributes': {'ESTRATO': '1',
#    'FID':
#      [-8243297, 520449],
#      [-8243286, 520437],
#      [-8243227, 520404],
#      [-8243206, 520433],
#      [-8243086, 520372]],
#     [[-8242415, 524043],
#      [-8242499, 524049],
#      [-8242527, 523637],
#      [-8242436, 523632],
#      [-8242444, 523480],
#      [-8242347, 523478],
#      [-8242327, 523846],
#      [-8242068, 523830],
#      [-8242033, 524212],
#      [-8242403, 524235],
#      [-8242415, 524043]]],
#    'spatialReference': {'wkid': 102100}}},
#  {'attributes': {'ESTRATO': '6',
#    'FID': 475,
#    'MUNICIPIO': 'BOGOTA',
#    'OBJECTID': 1443,
#    'Shape_Area': 1.57736171379e-05,
#    'Shape_Leng': 0.0235736723644},
#   'geometry': {'rings': [[[-8239984, 526406],
#      [-8240188, 526360],
#      [-8240008, 526365],
#      [-8240062, 526225],
#      [-8239984, 526115],
#      [-8240521, 526429],
#      [-8240420, 526616],
#      [-8240369, 526889],
#      [-8240279, 526863],
#      [-8240245, 526625],
#      [-8240124, 526585],
#      [-8239945, 526561],
#      [-8239925, 526468],
#      [-8239984, 526428],
#      [-8239984, 526406]]],
#    'spatialReference': {'wkid': 102100}}},
#  {'attributes': {'ESTRATO': '6',
#    'FID': 476,
#    'MUNICIPIO': 'BOGOTA',
#    'OBJECTID': 1444,
#    'Shape_Area': 9.70570803174e-06,
#    'Shape_Leng': 0.0138802659542},
#   'geometry': {'rings': [[[-8245113, 533015],
#      [-8245240, 532663],
#      [-8245431, 532887],
#      [-8245415, 533159],
#      [-8245375, 533343],
#      [-8245113, 533015]]],
#    'spatialReference': {'wkid': 102100}}},
#  {'attributes': {'ESTRATO': '6',
#    'FID': 477,
#    'MUNICIPIO': 'BOGOTA',
#    'OBJECTID': 1445,
#    'Shape_Area': 3.12922819439e-06,
#    'Shape_Leng': 0.00909159171738},
#   'geometry': {'rings': [[[-8241102, 536996],
#      [-8241083, 536947],
#      [-8241246, 537018],
#      [-8241437, 537074],
#      [-8241452, 537211],
#      [-8241107, 537067],
#      [-8241102, 536996]]],
#    'spatialReference': {'wkid': 102100}}}]

# %% [markdown]
# pero hay un problema

# %%
data_dict.get('layers')[0].get('featureSet').get('features')[0].get('geometry')
# Out:
# {'rings': [[[-8246601, 500775],
#    [-8246597, 500723],
#    [-8246649, 500727],
#    [-8246649, 500763],
#    [-8246601, 500775]]],
#  'spatialReference': {'wkid': 102100}}

# %% [markdown]
# ¿Que clase de coordenadas son esas?. Buscando en la documentación de arcGIS, aparece lo siguiente, depronto sirva.

# %% [markdown]
# "
# 102100 	WGS_1984_Web_Mercator_Auxiliary_Sphere
# PROJCS["WGS_1984_Web_Mercator_Auxiliary_Sphere",GEOGCS["GCS_WGS_1984",DATUM["D_WGS_1984",SPHEROID["WGS_1984",6378137.0,298.257223563]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Mercator_Auxiliary_Sphere"],PARAMETER["False_Easting",0.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",0.0],PARAMETER["Standard_Parallel_1",0.0],PARAMETER["Auxiliary_Sphere_Type",0.0],UNIT["Meter",1.0]]"

# %% [markdown]
# Investigando un poco mas sobre coordenadas de arcGIS, y el uso de la API en python de arcGIS, se descubre lo que se puede, de alguna manera "convertir" las coordenadas 102100 al conjunto de puntos (long, lat)

# %%
from arcgis.geometry import Geometry

pt = Geometry({
    "x": -8246601,
    "y": 500775,
    "spatialReference": {
        "wkid": 102100
    }
})

# %%
from arcgis.gis import GIS
from arcgis.geocoding import reverse_geocode

results = reverse_geocode(pt)
results
# Out:
# {'address': {'AddNum': '',
#   'Addr_type': 'Postal',
#   'Address': '',
#   'Block': '',
#   'City': 'Bogotá, D.C.',
#   'CountryCode': 'COL',
#   'District': '',
#   'LongLabel': '110531, COL',
#   'Match_addr': '110531',
#   'MetroArea': '',
#   'Neighborhood': '',
#   'PlaceName': '110531',
#   'Postal': '110531',
#   'PostalExt': '',
#   'Region': 'Bogotá, D.C.',
#   'Sector': '',
#   'ShortLabel': '110531',
#   'Subregion': '',
#   'Territory': '',
#   'Type': ''},
#  'location': {'spatialReference': {'latestWkid': 4326, 'wkid': 4326},
#   'x': -74.0804772033533,
#   'y': 4.493923603721151}}

# %% [markdown]
# Listo de esa manera puedo sacar la longitud y latitud, pero dios va a estar complicado.

# %% [markdown]
# ### 2. Encuesta:
# **DESCARTADO: ** No hay manera de referenciar un dato con una casa real. <br/>
# Nota: usan spss para el calculo de las estadisticas.

# %% [markdown]
# ### 3. [Mapa de Estratificación](http://www.sdp.gov.co/portal/page/portal/PortalSDP/InformacionTomaDecisiones/Estratificacion_Socioeconomica/Mapas):
# ** ACEPTADO** <br/>
# Va a ser complicado hacer la caja negra usando las imagenes de los mapas de la estratificación, estoy planeado hacer algo loco, y es entra la longitud y la latutid, la longitud se multiplica por un numero y se le suma la latitud, esto genera un numero unico por cada cordenada `(long, lat)`. Este numero unico se busca dentro de una matriz de numeros unicos, se toma la posicion de dicho ... QUIETO AHI. Se me acaba de ocurrir una mejor idea. :relaxed: Y se resume en el sigueinte lindo dibujo.
#
# <img src="./img/caja_no_tan_negra.jpg">

# %% [markdown]
# Y eso se hará, cada imagen se volvera un diccionario donde la clave es la `(long, lat)`, aunque en el algoritmo la clave esta basada en esas cordenadas, y el valor es el estrato. Pero hay un proceso que se debe realziar antes de esto. La fuente nos entrega los mapas en formato `pdf`, asi que hay que convertir dicho `pdf` a `png`. se descargan los pdf mediante un proceso no automatico. Luego se vuelven imagenes de forma automatica de la sigueinte manera:

# %%
filenames = !ls ./Target/2013_Bogota_Estratificacion/

# %%
filenames
# Out:
# ['antonio+nariño.pdf',
#  'barrios+unidos.pdf',
#  'Bosa.pdf',
#  'Chapinero.pdf',
#  'ciudad+bolivar.pdf',
#  'Engativa.pdf',
#  'Fontibon.pdf',
#  'Kennedy.pdf',
#  'la+candelaria.pdf',
#  'los+martires.pdf',
#  'puente+aranda.pdf',
#  'rafael+uribe.pdf',
#  'san+cristobal.pdf',
#  'santa+fe.pdf',
#  'Suba.pdf',
#  'Teusaquillo.pdf',
#  'Tunjuelito.pdf',
#  'Usaquen.pdf',
#  'Usme.pdf']

# %%
ok = False
for j,i in enumerate(filenames):
    # !convert -density 100 Target/2013_Bogota_Estratificacion/{i} -quality 100 ./Target/imgs/{j}.png
    ok = True
print(ok)

# %% [markdown]
# <center>
# <div style="width:50%">
# <img src="./data_target/img_bogota/prueba.png">
# </div>
# </center>

# %% [markdown]
# Y de esta manera quedan las imagenes, para ahorrar tiempo de ejecucion del algoritmo que se propone, es mejor hacerle unos recortes a las imagenes. Y despues de una aburrida jornada de edicion, quedan asi. Sin titulo, sin legenda, ni nada que pueda afectar mas adelante el algoritmo.

# %% [markdown]
# <center>
# <div style="width:50%">
# <img src="./data_target/img_bogota/zona_3.png">
# </div>
# </center>

# %% [markdown]
# #### 3.1 Analisis de las imagenes.
# Como se ve las imagnes tienen varios colores aparte de los colores de los estratos, estan las carreteras y los nombres de las calles y de las zonas importantes que se encuntran en morado, hay que revisar si esto afecta o no la calidad del algoritmo.

# %%
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# La idea consiste en revisar que en las imagenes se puedan dectectar los 6 colores de los estratos, los cuales son los siguientes.

# %% [markdown]
# ##### 3.1.1 Imagen unicamente cortada.
# Se estudia las imagenes, solamente cortadas. es decir las imagnes en las que en inkscape se les corto para reducir su tamaño, quitar la tabla de la leyenda, y dejarlas de un tamaño que sea facil de referenciar con la API de google.

# %%
img_cort = io.imread("./Target/imgs/zona_0.png")

# Tamaño de la imagen editada en inkscape
print("Dimensiones imagen original:", img.shape)

# En la edicion que se les hizo Inkscape le metio una cuarta capa a las imagenes. Asi que se la quitamos
img_dim_tres = img[:,:,0:3]
print("Dimensiones img a color: ", img_dim_tres.shape)

# Promedio:
img_mean =  np.mean(img_dim_tres, axis=2)
print("Dimensiones img a blanco y negro: ", img_mean.shape)

fig = plt.figure(figsize=(20,10))
plt.imshow(img_mean, cmap = plt.cm.Greys_r)
# Out:
# Dimensiones imagen original: (578, 1184, 4)
# Dimensiones img a color:  (578, 1184, 3)
# Dimensiones img a blanco y negro:  (578, 1184)

# %% [markdown]
# Surge una pregunta ¿Con las imagenes a blanco si se diferencian los 6 tonos de gris?

# %%
plt.hist(img_mean);
plt.xlim([100,300])
# Out:
# /home/daielchom/Templates/acanconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6097: UserWarning: 2D hist input should be nsamples x nvariables;
#  this looks transposed (shape is 578 x 1184)
#   '(shape is %d x %d)' % inp.shape[::-1])
# (100, 300)

# %% [markdown]
# ** PROBLEMA: ** el color blanco y gris, toman la mayor parte de los pixeles, se puede ver un pico en el color del estrato 3 y uno mas pequeño en el estrato 2, esto me pone a pensar ¿Que hacer?, ¿Como seguir?. Lo primero que se me viene a la cabeza es editar las imagenes para evitar tanto color blanco de las carreteras y algunos morados de los titulos, y para que cada color de estrato quede mas uniforme. seria depronto lo mas rapido y no tendria que cambiar el model que tengo.

# %%
img_dim_tres[200,650,:].mean()
# Out:
# 199.66666666666666

# %% [markdown]
# ##### 3.1.2 Imagen Arreglada:
# se modificaron los coleres de la imagen para ver si esto puede ayudar en que exista una informacion mas precisa para la caja negra.
# <img src="./data_target/img_bogota/new_colors/zona_0_color.png"/>

# %%
path = !ls Target/imgs/color_estrato

# %%
color_estratos = []
for i in path:
    color_estratos.append(io.imread("./Target/imgs/color_estrato/"+i))

# %%
color_estratos[0].shape
# Out:
# (30, 86, 4)

# %%
fig = plt.figure(figsize=(20,10))
for i in range(6):
    ax=fig.add_subplot(2,3,i+1)
    plt.imshow(color_estratos[i])
    ax.set_title("Estrato:" + str(i+1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])

# %% [markdown]
# Se pasan a blanco y negro para podre trabjarlas de manera mas facil.

# %%
estratos = {}
for j,i in enumerate(color_estratos):
    b_n = np.mean(i[:,:,0:3], axis=2)
    print(j, " ", np.unique(b_n))
    estratos.update({np.unique(b_n)[0]:j+1})
# Out:
# 0   [ 92.33333333]
# 1   [ 209.66666667]
# 2   [ 200.33333333]
# 3   [ 179.66666667]
# 4   [ 136.66666667]
# 5   [ 66.66666667]

# %% [markdown]
# Y estos serian los valores de color asignados a cada estrato.

# %%
estratos
# Out:
# {66.666666666666671: 6,
#  92.333333333333329: 1,
#  136.66666666666666: 5,
#  179.66666666666666: 4,
#  200.33333333333334: 3,
#  209.66666666666666: 2}

# %%
img_nuevo_color = io.imread("./Target/imgs/new_colors/zona_0_color.png")
img_nuevo_color.shape
# Out:
# (1156, 2368, 4)

# %%
img_nuevo_color_3 = img_nuevo_color[:,:,0:3]
img_nuevo_color_3.shape
# Out:
# (1156, 2368, 3)

# %%
print("Valores capa de más por Inkscape")
s = img_nuevo_color[:,:,3:4]
np.unique(s)
# Out:
# Valores capa de más por Inkscape
# array([255], dtype=uint8)

# %%
fig = plt.figure(figsize=(20,10))
plt.imshow(img_nuevo_color_mean, cmap = plt.cm.Greys_r)

# %%
img_nuevo_color_mean =  np.mean(img_nuevo_color_3, axis=2)

# %%
plt.hist(img_nuevo_color_mean);
plt.xlim([195,260])
# Out:
# /home/daielchom/Templates/acanconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6097: UserWarning: 2D hist input should be nsamples x nvariables;
#  this looks transposed (shape is 1156 x 2368)
#   '(shape is %d x %d)' % inp.shape[::-1])
# (195, 260)

# %%
print("ESTRATO 2", list(estratos.keys())[1], " - AMARILLO")
print("ESTRATO 3", list(estratos.keys())[2], " - AZUL")
# Out:
# ESTRATO 2 209.666666667  - AMARILLO
# ESTRATO 3 200.333333333  - AZUL

# %% [markdown]
# ##### 3.1.3 Imagen sin fondo

# %%
img_nuevo_color_sin = io.imread("./Target/imgs/new_colors/zona_0_color_sin.png")
print(img_nuevo_color_sin.shape)
img_nuevo_color_sin_3 = img_nuevo_color_sin[:,:,0:3]
print(img_nuevo_color_sin_3.shape)
# Out:
# (578, 1184, 4)
# (578, 1184, 3)

# %%
img_nuevo_color_sin_mean =  np.mean(img_nuevo_color_sin_3, axis=2)

# %%
plt.hist(img_nuevo_color_sin_mean);
plt.xlim([0,220])
# Out:
# /home/daielchom/Templates/acanconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6097: UserWarning: 2D hist input should be nsamples x nvariables;
#  this looks transposed (shape is 578 x 1184)
#   '(shape is %d x %d)' % inp.shape[::-1])
# (0, 220)

# %% [markdown]
# Comparando los 3 histogramas, es mejor el segundo. Aunque conlleva un tiempo arreglar las imagenes vale la pena, pues se pierden menos datos.

# %% [markdown]
# ### 3.2 Creación de diccionarios

# %% [markdown]
# de esta manera queda mas sencillo identificar entre los distintos colores de estratos.

# %%
KEY = "AIzaSyAiz9uvy5mPiVDrRHroTI9c6p0fdWRSw4I"
lista_localidades = []

# %%
for i in filenames:
    local = !http GET maps.googleapis.com/maps/api/geocode/json?address={i[:-4]}+bogota&key={KEY}
    lista_localidades.append(local)

# %%
lista_localidades
# Out:
# [['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "Antonio Nariño",',
#   '               "short_name" : "Antonio Nariño",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogota",',
#   '               "short_name" : "Bogota",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "Antonio Nariño, Bogotá, Bogota, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.598533,',
#   '                  "lng" : -74.084836',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.575912,',
#   '                  "lng" : -74.13165110000001',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.589684,',
#   '               "lng" : -74.09405799999999',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.598533,',
#   '                  "lng" : -74.084836',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.575912,',
#   '                  "lng" : -74.13165110000001',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJzYwoOMmeP44RF7iErav7Jg0",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "Barrios Unidos",',
#   '               "short_name" : "Barrios Unidos",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogota",',
#   '               "short_name" : "Bogota",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "Barrios Unidos, Bogotá, Bogota, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.689826,',
#   '                  "lng" : -74.05714589999999',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.6496909,',
#   '                  "lng" : -74.093626',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.664752,',
#   '               "lng" : -74.075214',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.689826,',
#   '                  "lng" : -74.05714589999999',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.6496909,',
#   '                  "lng" : -74.093626',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJ6WFCSP6aP44RIujZPPZisvY",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "Bosa",',
#   '               "short_name" : "Bosa",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogota",',
#   '               "short_name" : "Bogota",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "Bosa, Bogotá, Bogota, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.655578,',
#   '                  "lng" : -74.151594',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.595705,',
#   '                  "lng" : -74.223637',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.609896,',
#   '               "lng" : -74.184721',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.655578,',
#   '                  "lng" : -74.151594',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.595705,',
#   '                  "lng" : -74.223637',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJ6Sh07G-eP44RAdG49C4lxUY",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "Chapinero",',
#   '               "short_name" : "Chapinero",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogota",',
#   '               "short_name" : "Bogota",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "Chapinero, Bogotá, Bogota, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.686946100000001,',
#   '                  "lng" : -73.99197699999999',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.61045,',
#   '                  "lng" : -74.06841899999999',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.649656,',
#   '               "lng" : -74.063097',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.686946100000001,',
#   '                  "lng" : -73.99197699999999',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.61045,',
#   '                  "lng" : -74.06841899999999',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJgwW_iJ6QP44Rc7wFsOAC5M4",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "Ciudad Bolívar",',
#   '               "short_name" : "Ciudad Bolívar",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogota",',
#   '               "short_name" : "Bogota",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "Ciudad Bolívar, Bogotá, Bogota, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.599952,',
#   '                  "lng" : -74.119963',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.4690151,',
#   '                  "lng" : -74.187928',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.579524,',
#   '               "lng" : -74.15742890000001',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.599952,',
#   '                  "lng" : -74.119963',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.4690151,',
#   '                  "lng" : -74.187928',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJb2A-s-6hP44RCtQ56Pk_xgo",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "Engativá",',
#   '               "short_name" : "Engativá",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogota",',
#   '               "short_name" : "Bogota",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "Engativá, Bogotá, Bogota, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.740226,',
#   '                  "lng" : -74.076881',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.654082,',
#   '                  "lng" : -74.1604409',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.70846,',
#   '               "lng" : -74.11167999999999',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.740226,',
#   '                  "lng" : -74.076881',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.654082,',
#   '                  "lng" : -74.1604409',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJhTa7MamcP44R9A_fFp_Ee3c",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "Fontibón",',
#   '               "short_name" : "Fontibón",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "Fontibón, Bogotá, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.7175369,',
#   '                  "lng" : -74.10312499999999',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.637513999999999,',
#   '                  "lng" : -74.17624099999999',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.673689,',
#   '               "lng" : -74.143671',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.7175369,',
#   '                  "lng" : -74.10312499999999',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.637513999999999,',
#   '                  "lng" : -74.17624099999999',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJHaPSpV-cP44RRgySMYfH-aU",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "Kennedy",',
#   '               "short_name" : "Kennedy",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogota",',
#   '               "short_name" : "Bogota",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "Kennedy, Bogotá, Bogota, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.6647869,',
#   '                  "lng" : -74.118217',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.595104,',
#   '                  "lng" : -74.1855389',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.63113,',
#   '               "lng" : -74.148473',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.6647869,',
#   '                  "lng" : -74.118217',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.595104,',
#   '                  "lng" : -74.1855389',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJeWMYwSCcP44RrHXiIb6MxHI",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "La Candelaria",',
#   '               "short_name" : "La Candelaria",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "La Candelaria, Bogotá, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.603489,',
#   '                  "lng" : -74.05983909999999',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.589309,',
#   '                  "lng" : -74.082229',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.597014,',
#   '               "lng" : -74.0728759',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.603489,',
#   '                  "lng" : -74.05983909999999',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.589309,',
#   '                  "lng" : -74.082229',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJy3nPRKiZP44RMROn2mQYjaU",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "Los Mártires",',
#   '               "short_name" : "Los Mártires",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogota",',
#   '               "short_name" : "Bogota",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "Los Mártires, Bogotá, Bogota, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.6248939,',
#   '                  "lng" : -74.072839',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.591946,',
#   '                  "lng" : -74.10708799999999',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.604824,',
#   '               "lng" : -74.085503',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.6248939,',
#   '                  "lng" : -74.072839',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.591946,',
#   '                  "lng" : -74.10708799999999',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJGRtzwW-ZP44RyhT1aOU51Wc",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "Puente Aranda",',
#   '               "short_name" : "Puente Aranda",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogota",',
#   '               "short_name" : "Bogota",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "Puente Aranda, Bogotá, Bogota, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.645219,',
#   '                  "lng" : -74.0828719',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.593724,',
#   '                  "lng" : -74.138036',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.614995,',
#   '               "lng" : -74.114656',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.645219,',
#   '                  "lng" : -74.0828719',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.593724,',
#   '                  "lng" : -74.138036',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJtbVi8lqZP44R4OCH4LRAv58",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "Rafael Uribe Uribe, Bogotá",',
#   '               "short_name" : "Rafael Uribe Uribe, Bogotá",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogota",',
#   '               "short_name" : "Bogota",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "Rafael Uribe Uribe, Bogotá, Bogotá, Bogota, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.5926919,',
#   '                  "lng" : -74.09447399999999',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.5394309,',
#   '                  "lng" : -74.130819',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.578436,',
#   '               "lng" : -74.110488',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.5926919,',
#   '                  "lng" : -74.09447399999999',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.5394309,',
#   '                  "lng" : -74.130819',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJM95Jj7eYP44RZP91dTHHG9Y",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "San Cristóbal",',
#   '               "short_name" : "San Cristóbal",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogota",',
#   '               "short_name" : "Bogota",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "San Cristóbal, Bogotá, Bogota, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.5894131,',
#   '                  "lng" : -74.02683089999999',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.508548,',
#   '                  "lng" : -74.10622499999999',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.5591989,',
#   '               "lng" : -74.091471',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.5894131,',
#   '                  "lng" : -74.02683089999999',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.508548,',
#   '                  "lng" : -74.10622499999999',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJyTEmr4yYP44RyEyAcrR7BTk",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "Santa Fe",',
#   '               "short_name" : "Santa Fe",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogota",',
#   '               "short_name" : "Bogota",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "Santa Fe, Bogotá, Bogota, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.628019999999999,',
#   '                  "lng" : -73.992493',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.557937,',
#   '                  "lng" : -74.0888231',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.611238,',
#   '               "lng" : -74.070245',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.628019999999999,',
#   '                  "lng" : -73.992493',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.557937,',
#   '                  "lng" : -74.0888231',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJaU8k9SSaP44RoS6Stp4wY8g",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "Suba",',
#   '               "short_name" : "Suba",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogota",',
#   '               "short_name" : "Bogota",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "Suba, Bogotá, Bogota, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.8371311,',
#   '                  "lng" : -74.034426',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.6857419,',
#   '                  "lng" : -74.131559',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.740881,',
#   '               "lng" : -74.08381',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.8371311,',
#   '                  "lng" : -74.034426',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.6857419,',
#   '                  "lng" : -74.131559',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJFwRwnVCEP44RFE_5QOlpzcc",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "Teusaquillo",',
#   '               "short_name" : "Teusaquillo",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogota",',
#   '               "short_name" : "Bogota",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "Teusaquillo, Bogotá, Bogota, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.666132999999999,',
#   '                  "lng" : -74.064605',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.615468,',
#   '                  "lng" : -74.11037899999999',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.635807,',
#   '               "lng" : -74.07944999999999',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.666132999999999,',
#   '                  "lng" : -74.064605',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.615468,',
#   '                  "lng" : -74.11037899999999',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJN3NkpeqbP44RWZMQLjdYo28",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "Tunjuelito",',
#   '               "short_name" : "Tunjuelito",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogota",',
#   '               "short_name" : "Bogota",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "Tunjuelito, Bogotá, Bogota, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.5959911,',
#   '                  "lng" : -74.119795',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.531416,',
#   '                  "lng" : -74.15693499999999',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.569067,',
#   '               "lng" : -74.13457300000002',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.5959911,',
#   '                  "lng" : -74.119795',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.531416,',
#   '                  "lng" : -74.15693499999999',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJKyHw51afP44RlL4iA4jg4as",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "Usaquén",',
#   '               "short_name" : "Usaquén",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogota",',
#   '               "short_name" : "Bogota",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "Usaquén, Bogotá, Bogota, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.825362999999999,',
#   '                  "lng" : -74.0004491',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.664612,',
#   '                  "lng" : -74.05714589999999',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.695457999999999,',
#   '               "lng" : -74.031194',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.825362999999999,',
#   '                  "lng" : -74.0004491',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.664612,',
#   '                  "lng" : -74.05714589999999',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJ61tOXYCPP44Rb3xHQhxhUwg",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}'],
#  ['{',
#   '   "results" : [',
#   '      {',
#   '         "address_components" : [',
#   '            {',
#   '               "long_name" : "Usme",',
#   '               "short_name" : "Usme",',
#   '               "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogotá",',
#   '               "short_name" : "Bogotá",',
#   '               "types" : [ "locality", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Bogota",',
#   '               "short_name" : "Bogota",',
#   '               "types" : [ "administrative_area_level_1", "political" ]',
#   '            },',
#   '            {',
#   '               "long_name" : "Colombia",',
#   '               "short_name" : "CO",',
#   '               "types" : [ "country", "political" ]',
#   '            }',
#   '         ],',
#   '         "formatted_address" : "Usme, Bogotá, Bogota, Colombia",',
#   '         "geometry" : {',
#   '            "bounds" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.546443,',
#   '                  "lng" : -74.0560129',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.459464,',
#   '                  "lng" : -74.13452199999999',
#   '               }',
#   '            },',
#   '            "location" : {',
#   '               "lat" : 4.506367,',
#   '               "lng" : -74.107952',
#   '            },',
#   '            "location_type" : "APPROXIMATE",',
#   '            "viewport" : {',
#   '               "northeast" : {',
#   '                  "lat" : 4.546443,',
#   '                  "lng" : -74.0560129',
#   '               },',
#   '               "southwest" : {',
#   '                  "lat" : 4.459464,',
#   '                  "lng" : -74.13452199999999',
#   '               }',
#   '            }',
#   '         },',
#   '         "place_id" : "ChIJt9qBZPmjP44R4KJ7vKBwMqQ",',
#   '         "types" : [ "political", "sublocality", "sublocality_level_1" ]',
#   '      }',
#   '   ],',
#   '   "status" : "OK"',
#   '}']]

# %%
# %%writefile ./Target/localidad_estrato_bruto
# Out:
# Writing ./Target/localidad_estrato_bruto

# %%
import json
archivo = open("./Target/localidad_estrato_bruto","w")
for i in lista_localidades:
    archivo.write(json.dumps(i)+"\n")
archivo.close()

# %%
Xmax = 0
Xmin = 0
Ymax = 0
Ymin = 0
cont = 0
gps_list = []
for i in lista_localidades:
    Xmax =  i[30:31][0][26:]
    Ymax =  i[29:30][0][26:-1]
    Xmin =  i[34:35][0][26:]
    Ymin =  i[33:34][0][26:-1]
    gps_list.append([float(Xmax), float(Ymax), float(Xmin), float(Ymin)])
    cont+=1

# %%
# %%writefile ./Target/localidad_estrato
# Out:
# Overwriting ./Target/localidad_estrato

# %%
archivo = open("./Target/localidad_estrato","w")
for i in range(len(gps_list)):
    print("LOCALIDAD ",i+1,": ",filenames[i][:-4])
    print("COORDENADAS",gps_list[i])
    print("")
    archivo.write(str(filenames[i][:-4])+" "+str(gps_list[i])+"\n")
archivo.close()
# Out:
# LOCALIDAD  1 :  antonio+nariño
# COORDENADAS [-74.084836, 4.598533, -74.13165110000001, 4.575912]
#
# LOCALIDAD  2 :  barrios+unidos
# COORDENADAS [-74.0571459, 4.689826, -74.093626, 4.6496909]
#
# LOCALIDAD  3 :  Bosa
# COORDENADAS [-74.151594, 4.655578, -74.223637, 4.595705]
#
# LOCALIDAD  4 :  Chapinero
# COORDENADAS [-73.99197699999999, 4.686946100000001, -74.06841899999999, 4.61045]
#
# LOCALIDAD  5 :  ciudad+bolivar
# COORDENADAS [-74.119963, 4.599952, -74.187928, 4.4690151]
#
# LOCALIDAD  6 :  Engativa
# COORDENADAS [-74.076881, 4.740226, -74.1604409, 4.654082]
#
# LOCALIDAD  7 :  Fontibon
# COORDENADAS [-74.10312499999999, 4.7175369, -74.17624099999999, 4.637513999999999]
#
# LOCALIDAD  8 :  Kennedy
# COORDENADAS [-74.118217, 4.6647869, -74.1855389, 4.595104]
#
# LOCALIDAD  9 :  la+candelaria
# COORDENADAS [-74.05983909999999, 4.603489, -74.082229, 4.589309]
#
# LOCALIDAD  10 :  los+martires
# COORDENADAS [-74.072839, 4.6248939, -74.10708799999999, 4.591946]
#
# LOCALIDAD  11 :  puente+aranda
# COORDENADAS [-74.0828719, 4.645219, -74.138036, 4.593724]
#
# LOCALIDAD  12 :  rafael+uribe
# COORDENADAS [-74.09447399999999, 4.5926919, -74.130819, 4.5394309]
#
# LOCALIDAD  13 :  san+cristobal
# COORDENADAS [-74.0268309, 4.5894131, -74.106225, 4.508548]
#
# LOCALIDAD  14 :  santa+fe
# COORDENADAS [-73.992493, 4.628019999999999, -74.0888231, 4.557937]
#
# LOCALIDAD  15 :  Suba
# COORDENADAS [-74.034426, 4.8371311, -74.131559, 4.6857419]
#
# LOCALIDAD  16 :  Teusaquillo
# COORDENADAS [-74.064605, 4.666132999999999, -74.110379, 4.615468]
#
# LOCALIDAD  17 :  Tunjuelito
# COORDENADAS [-74.119795, 4.5959911, -74.15693499999999, 4.531416]
#
# LOCALIDAD  18 :  Usaquen
# COORDENADAS [-74.0004491, 4.825362999999999, -74.0571459, 4.664612]
#
# LOCALIDAD  19 :  Usme
# COORDENADAS [-74.0560129, 4.546443, -74.13452199999999, 4.459464]

# %%
path_prueba = "Target"

# %%
def get_estrato(pixel):
    return estratos.get(pixel)

get_estrato(200.33333333333334)

# %%
def crea_diccionario(img, Xmax, Xmin, Ymax, Ymin):
    lat_init = Ymin
    paramLong = (Xmax - Xmin) / img.shape[0]
    paramLat = (Ymax - Ymin) / img.shape[1]
    dict_result = {}
    for i in range(img.shape[0]):
        long_init = Xmin 
        for j in range(img[1]):
            pixel = img[i][j]
            if pixel != 0:
                estrato = get_estrato(img[i][j])
                posicion = long_init*(0.3) + lat_init
                dict_result.update({posicion:estrato})
            long_init += paramLong
        lat_init += paramLat
    return dict_result

# %%
dict_uno = crea_diccionario(img_mean, gps_list[0], gps_list[2], gps_list[1], gps_list[3])

# %% [markdown]
# # BUENO, HAY QUE HACER PAUSE AQUI. EL PROFESOR AL VER EL TRABAJO REALIZO HASTA AHORA SUGIRIO UN CAMBIO EN LA CAJA NEGRA, TANTO EN LA ENTRADA COMO EN LA SALIDA. ASI QUE PARA NO HACER MAS LARGO ESTE NOTEBOOK SE CREARA OTRO DONDE SE TRABAJE LA NUEVA PROPUESTA.
